# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Dataset_English_Hindi.csv',encoding='UTF-8')

# %%
df.sample(20)
# Out:
#                                                  English  \
# 58039           is to build viable systems on the ground
# 61308  Your support and encouragement are very import...
# 20483  suraksha khabar line:terorism&international te...
# 79307             One mango, two mangoes, three mangoes,
# 19360         where we're holding both beliefs together,
# 41346  Only those Financial Bills may be Money Bills ...
# 29456  The water is used even in the preparation of a...
# 54102  While penny pinching on the cast , the filmmak...
# 23898  And look at Ragav, that moment when his face c...
# 20986  During the days of clear sky (Without fog and ...
# 65807    They demanded that you be made prime minister .
# 51419  Which Vaidik Vidvan have a right for doing Yag...
# 47939  Even during the early fifties , the demand was...
# 6149   It is able to do so because the human brain ha...
# 50113              we educate our leaders is fundamental
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84944 entries, 0 to 84943
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   English  84942 non-null  object
#  1   Hindi    84742 non-null  object
# dtypes: object(2)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# English      2
# Hindi      202
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# English    0
# Hindi      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1554

# %%
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83186 entries, 0 to 84943
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   English  83186 non-null  object
#  1   Hindi    83186 non-null  object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
df['Hindi']=df['Hindi'].apply(lambda x:'start ' + x + ' end');
df['English']=df['English'].apply(lambda x:'start ' + x + ' end');

# %%
df
# Out:
#                                                  English  \
# 0                                        start Help! end
# 1                                        start Jump. end
# 2                                        start Jump. end
# 3                                        start Jump. end
# 4                                       start Hello! end
# ...                                                  ...
# 84939  start Tendulkar in his one-day career scored h...
# 84940  start 73. Temple of the Universe is an island ...
# 84941  start And so every few weeks teachers could si...
# 84942  start There is no doubt that diabetes seems be...
# 84943  start If you 're worried - for example about t...
#
#                                                    Hindi
# 0                                        start बचाओ! end
# 1                                        start उछलो. end
# 2                                        start कूदो. end
# ...

# %%
max_word_in_eng_sen=max(df['English'].str.split().str.len())
min_word_in_eng_sen=min(df['English'].str.split().str.len())
print("Max words in eng=",int(max_word_in_eng_sen))
print("Min words in eng=",int(min_word_in_eng_sen))

max_word_in_hin_sen=max(df['Hindi'].str.split().str.len())
min_word_in_hin_sen=min(df['Hindi'].str.split().str.len())
print("Max words in hindi=",int(max_word_in_hin_sen))
print("Min words in hindi=",int(min_word_in_hin_sen))
# Out:
# Max words in eng= 351
# Min words in eng= 3
# Max words in hindi= 316
# Min words in hindi= 3

# %%
df=df[(df['English'].str.split().str.len()<10)&(df['Hindi'].str.split().str.len()<10)]

# %%
max_word_in_eng_sen=max(df['English'].str.split().str.len())
min_word_in_eng_sen=min(df['English'].str.split().str.len())
print("Max words in eng=",int(max_word_in_eng_sen))
print("Min words in eng=",int(min_word_in_eng_sen))

max_word_in_hin_sen=max(df['Hindi'].str.split().str.len())
min_word_in_hin_sen=min(df['Hindi'].str.split().str.len())
print("Max words in hindi=",int(max_word_in_hin_sen))
print("Min words in hindi=",int(min_word_in_hin_sen))
# Out:
# Max words in eng= 9
# Min words in eng= 3
# Max words in hindi= 9
# Min words in hindi= 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17734 entries, 0 to 84929
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   English  17734 non-null  object
#  1   Hindi    17734 non-null  object
# dtypes: object(2)
# memory usage: 415.6+ KB

# %%
list_Hindi=[]
list_English=[]
def formlist(text,list):
    list.append(text)

# %%
df['English'].apply(lambda x:formlist(x,list_English))
df['Hindi'].apply(lambda x:formlist(x,list_Hindi))

# %%
print(list_English[0]," => ",list_Hindi[0])
# Out:
# start Help! end  =>  start बचाओ! end

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# %%
def total_words(list):
    tokenizer=Tokenizer(num_words=100)
    tokenizer.fit_on_texts(list)
    return max(tokenizer.word_index.values())

# %%
total_English_word=total_words(list_English)
total_Hindi_word=total_words(list_Hindi)
print('total_words_in_English=',total_English_word)
print('total_words_in_Hindi=',total_Hindi_word)
# Out:
# total_words_in_English= 11414
# total_words_in_Hindi= 12131

# %%
English_tokenizer=Tokenizer(total_English_word)
English_tokenizer.fit_on_texts(list_English)

Hindi_tokenizer=Tokenizer(total_Hindi_word)
Hindi_tokenizer.fit_on_texts(list_Hindi)

# %%
def tokenize_pad(list,max_len,num_words):
    tokenizer=Tokenizer(num_words=num_words)
    tokenizer.fit_on_texts(list)
    sequence=tokenizer.texts_to_sequences(list)
    padded=pad_sequences(sequence,padding='post',maxlen=max_len)
    return padded

# %%
English_pad=tokenize_pad(list_English,max_word_in_eng_sen,total_English_word)
Hindi_pad=tokenize_pad(list_Hindi,max_word_in_hin_sen,total_Hindi_word)

# %%
from keras.layers import Input, Embedding, BatchNormalization, LSTM, Dense
from keras.models import Model
from keras.optimizers import Nadam

latent_dim = 200
doc_length = max_word_in_eng_sen
# Encoder model
encoder_input = Input(shape=(doc_length,), name='encoder_input')
x = Embedding(total_English_word, latent_dim, name='English_word_embedding')(encoder_input)
x = BatchNormalization(name='Scaling_English_vector')(x)
x=LSTM(latent_dim,return_sequences=True,name='Encoder_LSTM1')(x)
_,state_h,state_c = LSTM(latent_dim, return_state=True,return_sequences=True, name='Encoder_LSTM2')(x)
encoder_model = Model(inputs=encoder_input, outputs=[state_h,state_c], name='Encoder_Model')
encoder_out_h,encoder_out_c= encoder_model(encoder_input)

# Decoder model
decoder_input = Input(shape=(None,), name='Decoder_input')
y = Embedding(total_Hindi_word, latent_dim, name='Hindi_word_embedding')(decoder_input)
y = BatchNormalization(name='Scaling_mean_vector')(y)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True, name='Decoder_LSTM')
output_n, _, _ = decoder_lstm(y, initial_state=[encoder_out_h,encoder_out_c])
output_norm = BatchNormalization(name='Decoder_lstm_output_norm')(output_n)

# Dense layer
dense_layer = Dense(total_Hindi_word, activation='softmax', name='Final_dense_layer')
prob_out = dense_layer(output_norm)

# Sequence_to_Sequence_Model
seq2seq_Model = Model([encoder_input, decoder_input], prob_out)
seq2seq_Model.compile(optimizer=Nadam(learning_rate=0.001), loss='sparse_categorical_crossentropy')
seq2seq_Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  Decoder_input (InputLayer)     [(None, None)]       0           []
#
#  Hindi_word_embedding (Embeddin  (None, None, 200)   2426200     ['Decoder_input[0][0]']
#  g)
#
#  encoder_input (InputLayer)     [(None, 9)]          0           []
#
#  Scaling_mean_vector (BatchNorm  (None, None, 200)   800         ['Hindi_word_embedding[0][0]']
#  alization)
#
#  Encoder_Model (Functional)     [(None, 200),        2925200     ['encoder_input[0][0]']
#                                  (None, 200)]
#
#  Decoder_LSTM (LSTM)            [(None, None, 200),  320800      ['Scaling_mean_vector[0][0]',
#                                  (None, 200),                     'Encoder_Model[0][0]',
#                                  (None, 200)]                     'Encoder_Model[0][1]']
#
# ...

# %%
import numpy as np
np.save('English_vecs.npy',English_pad)
np.save('Hindi_vecs.npy',Hindi_pad)


def load_encoder_inputs(encoder_np_vecs='English_vecs.npy'):
    vectorized_body=np.load(encoder_np_vecs)
    encoder_input_data=vectorized_body
    doc_length=encoder_input_data.shape[1]
    print(f'Shape of the encoder input:{encoder_input_data.shape}')
    return encoder_input_data ,doc_length


def load_decoder_inputs(decoder_np_vecs='Hindi_vecs.npy'):
    vectorized_title=np.load(decoder_np_vecs)
    decoder_input_data=vectorized_title[:,:-1]
    decoder_target_data=vectorized_title[:,1:]
    print(f'Shape of the decoder input:{decoder_input_data.shape}')
    print(f'Shape of the decoder target :{decoder_target_data.shape}')
    return decoder_input_data,decoder_target_data

decoder_input_data,decoder_target_data=load_decoder_inputs('Hindi_vecs.npy')
encoder_input_data,doc_length=load_encoder_inputs('English_vecs.npy')
# Out:
# Shape of the decoder input:(17734, 8)
# Shape of the decoder target :(17734, 8)
# Shape of the encoder input:(17734, 9)

# %%
from keras.callbacks import CSVLogger,ModelCheckpoint
script_name_base='seq2seq'
csv_logger=CSVLogger('{:}.log'.format(script_name_base))
model_checkpoint=ModelCheckpoint('{:}.epoch{{epoch:02d}}-val{{val_loss:.5f}}.hdf5'.format(script_name_base),save_best_only=True)
batch_size=100
epochs=25
history=seq2seq_Model.fit([encoder_input_data,decoder_input_data], np.expand_dims(decoder_target_data,axis=1),batch_size=batch_size,epochs=epochs,validation_split=0.12,
                          callbacks=[csv_logger,model_checkpoint])
# Out:
# Epoch 1/25
# 157/157 [==============================] - 140s 822ms/step - loss: 4.7680 - val_loss: 8.0720
# Epoch 2/25
# 157/157 [==============================] - 126s 806ms/step - loss: 3.4565 - val_loss: 7.6382
# Epoch 3/25
# 157/157 [==============================] - 123s 787ms/step - loss: 2.6133 - val_loss: 6.1489
# Epoch 4/25
# 157/157 [==============================] - 125s 795ms/step - loss: 1.8110 - val_loss: 3.4788
# Epoch 5/25
# 157/157 [==============================] - 122s 776ms/step - loss: 1.1434 - val_loss: 3.3035
# Epoch 6/25
# 157/157 [==============================] - 127s 809ms/step - loss: 0.6453 - val_loss: 3.5128
# Epoch 7/25
# 157/157 [==============================] - 131s 835ms/step - loss: 0.3490 - val_loss: 3.6240
# Epoch 8/25
# 157/157 [==============================] - 120s 764ms/step - loss: 0.1930 - val_loss: 3.6702
# Epoch 9/25
# 157/157 [==============================] - 119s 760ms/step - loss: 0.1082 - val_loss: 3.8137
# Epoch 10/25
# ...

# %%
from keras.models import load_model
import numpy as np

class Eng_to_Hindi_Inference:
    def __init__(self, model_path, English_tokenizer, Hindi_tokenizer, doc_length, beam_width=2):
        self.model = load_model(model_path)
        self.English_tokenizer = English_tokenizer
        self.Hindi_tokenizer = Hindi_tokenizer
        self.doc_length = doc_length
        self.beam_width = beam_width

    def tokenize_English(self, English_text):
        English_text = 'start ' + English_text + ' end'
        sequences = self.English_tokenizer.texts_to_sequences([English_text])
        padded_sequences = pad_sequences(sequences, maxlen=self.doc_length, padding='post')
        return padded_sequences

    def beam_search(self, encoded_English, max_length=8):
        start_token = self.Hindi_tokenizer.word_index['start']
        end_token = self.Hindi_tokenizer.word_index['end']

        sequences = [[start_token]]
        scores = [0]

        while len(sequences[0]) < max_length:
            all_candidates = []

            for i in range(len(sequences)):
                sequence = sequences[i]
                last_token = sequence[-1]
                if last_token == end_token:
                    continue

                target_seq = np.zeros((1, len(sequence)))
                for t, token in enumerate(sequence):
                    target_seq[0, t] = token

                predictions = self.model.predict([encoded_English, target_seq])
                next_token_probs = predictions[0, -1, :]
                best_tokens = np.argsort(next_token_probs)[-self.beam_width:]

                for token in best_tokens:
                    new_sequence = sequence + [token]
                    new_score = scores[i] - np.log(next_token_probs[token])
                    all_candidates.append((new_sequence, new_score))

            if not all_candidates:
                break

            ordered = sorted(all_candidates, key=lambda tup: tup[1])
            sequences = [seq for seq, _ in ordered]
            scores = [score for _, score in ordered]

        best_sequence = sequences[0]
        decoded_sequence = [self.Hindi_tokenizer.index_word[token] for token in best_sequence]
        return ' '.join(decoded_sequence[1:-1])

    def generate_Hindi(self, English_text):
        encoded_English = self.tokenize_English(English_text)
        generated_meaning = self.beam_search(encoded_English)
        return generated_meaning

# %%
Eng_to_Hindi_inference = Eng_to_Hindi_Inference('/content/seq2seq.epoch05-val3.30352.hdf5', English_tokenizer, Hindi_tokenizer, doc_length, beam_width=3)
English_text = "Where are you going?"
predicted_Hindi = Eng_to_Hindi_inference.generate_Hindi(English_text)
print("Predicted Hindi Translation:", predicted_Hindi)
# Out:
# ...
# 1/1 [==============================] - 0s 52ms/step
# Predicted Hindi Translation: आप कहाँ जा रहे हैं ।
